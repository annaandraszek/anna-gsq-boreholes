# %%
import borehole_tables as bt

# %%
clf2 = bt.train(0)
# Out:
# training with all labelled samples
# test set size:  0.2
# [Pipeline] .......... (step 1 of 3) Processing list2str, total=   0.0s
# [Pipeline] ............. (step 2 of 3) Processing tfidf, total=   0.6s
# [Pipeline] ............... (step 3 of 3) Processing cnb, total=   0.0s
# Test set results:
# 0.8966942148760331
# [[596  74]
#  [  1  55]]
# For manually annotated:
# 0.9181141439205955
# [[3079  291]
#  [   6  251]]

# %%
res = bt.get_bh_tables_from_docid(['2646', '44448', '32730', '37802', '44603'])
# Out:
# Getting borehole tables for  2646
# Num of all tables:  3 , num of borehole tables:  2
# Borehole tables:
#     Bore  Total Depth  Depth to Coal  Coal Thickness
# 0     NaN         ft.            ft.             ft.
# 1   -A35          350            185               6
# 2    A36          302             NaN             NaN
# 3    A37          400             NaN             NaN
# 4    A38          130             NaN             NaN
# 5   A38A          115             NaN             NaN
# 6    A39          158             NaN             NaN
# 7    A40          188            176               9
# 8    A41          175             NaN             NaN
# 9    A42          457            455              10
# 10   A43          110             NaN             NaN
# 11   A44          200             NaN             NaN
#         Bore  Seam Thickness  Recovery  Moisture   Ash  Vol. M.   S.I.
# 0         NaN             NaN  e F1.45         %     %        %     NaN
# ...

# %%
bt.train(n_queries=20)
# Out:
#            From            To                          Description
# 0          6:00          7:00                       Travel to site
# 1          7:00          7:45                    Pre start Toolbox
# 2     7:45 8:00          8:00                       Flush hole 154
# 3            NaN        17:00                    Core ahead to 57m
# 5   17:00 17:30   17:30 18:00   Flush hole Packup Travel from site
# 6         18:00            NaN                                  NaN
# 27           NaN           NaN                  Well site Visitors
# 28         From            To                          Description
# 29         7:15         15:15                             Jim Cole
# 32          BHA            NaN            99mm HQ Surface bit 7.2m
# 33           NaN           NaN           Operations for next 24hrs
# 34           NaN           NaN                          Core ahead
#
# 69109 table:  42
#
# queries:  20
# predict proba of this sample:  [[0.83384217 0.16615783]]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f39046bd8d8f> in <module>
# ----> 1 res.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
res.loc[res['DocID'] == '37802']
# Out:
#     DocID TableNum                                            Columns  Class  \
# 23  37802       10  ['From (m) ', 'To (m) ', 'Hole Diameter & Dril...    1.0
# 51  37802       38  ['Depth From ', 'Depth To ', 'Average Gas unit...    1.0
#
#        proba
# 23  0.961729
# 51  0.668130

# %%
res.loc[res['DocID'] == '32730']
# Out:
#     DocID TableNum                                            Columns  Class  \
# 11  32730        2  ['HOLE ', 'EASTING ', 'NORTHING ', 'RL ', 'DRI...    1.0
#
#        proba
# 11  0.999997

# %%
res['Columns'][8]
# Out:
# "['SDA No ', 'Lab Job No ', 'Sample From ', 'Sample to ', 'Assay Type ', 'NWQ05DXJ011 ', 'TV05101133 ', 'ARA43425 ', 'ARA43573 ', 'ME-ICP41 & Au AA21 ', 'NWQ05DXJ012 ', 'TV05101134 ', 'EB22116 ', 'EB22145 ', 'ME-ICP61 & Au AA21 ']"

# %%
clf = bt.train(0)
# eli5.show_weights(clf)
# Out:
# training with all labelled samples
# test set size:  0.2
# [Pipeline] .......... (step 1 of 3) Processing list2str, total=   0.0s
# [Pipeline] ............. (step 2 of 3) Processing tfidf, total=   0.4s
# [Pipeline] ............... (step 3 of 3) Processing cnb, total=   0.0s
# Test set results:
# 0.9411764705882353
# [[106   3]
#  [  4   6]]
# For manually annotated:
# 0.9865319865319865
# [[533   4]
#  [  4  53]]

# %%
df = bt.create_dataset(['2646', '44448', '32730', '37802', '44603'], save=False)
df
# Out:
#      DocID TableNum                                            Columns
# 0     2646        1  [Unnamed: 0, Page , OBJECTIVES , DRILLING , GE...
# 1     2646        2  [Bore , Total Depth , Depth to Coal , Coal Thi...
# 2     2646        3  [Bore , Seam Thickness , Recovery , Moisture ,...
# 3    44448        1  [TITLE: , EXPLORATION PERMIT FOR MINERALS No 9...
# 4    44448        2                                                 []
# ..     ...      ...                                                ...
# 216  44603      136  [Unnamed: 0, Unnamed: 1, generally oblique or ...
# 217  44603      137  [Telephone: , Fax: (02) 4579 1290 , Unnamed: 3...
# 218  44603      138  [t.b refer to , Unnamed: 1, subsamples , from ...
# 219  44603      139  [Unnamed: 0, EXPLORATION , LIMITED , Unnamed: ...
# 220  44603      140  [Unnamed: 0, Unnamed: 1, Unnamed: 2, felsic , ...
#
# [221 rows x 3 columns]

# %%
df = df.loc[df['Columns'].str.len() > 0]
res = bt.get_borehole_tables(df, masked=True)
res
# Out:
# C:\Users\andraszeka\OneDrive - ITP (Queensland Government)\gsq-boreholes\textracting\borehole_tables.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Columns'] = df['Columns'].astype(str)
# C:\Users\andraszeka\OneDrive - ITP (Queensland Government)\gsq-boreholes\textracting\bookmarker\machine_learning_helper.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[y_column] = classes
# ...

# %%
import borehole_tables

borehole_tables.train(n_queries=0)
# Out:
# training with all labelled samples
# test set size:  0.2
# [Pipeline] .......... (step 1 of 3) Processing list2str, total=   0.0s
# [Pipeline] ............. (step 2 of 3) Processing tfidf, total=   0.3s
# [Pipeline] ............... (step 3 of 3) Processing cnb, total=   0.0s
# Test set results:
# 0.9652173913043478
# [[100   2]
#  [  2  11]]
# For manually annotated:
# 0.9910714285714286
# [[491   2]
#  [  3  64]]

# %%
from __future__ import print_function
import numpy as np
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from transformers import pipeline
from transformers import *

# %%
nlp = pipeline('fill-mask')
nlp(f'The relinquished portions of EPM 11177 are located south-east and south-west of {nlp.tokenizer.mask_token} (see Drawing 333.A4.02) and are within Roxmere Holding (PH 4893)and The Gorge Holding (PH 2330). The relinquished areas lie on the Cloncurry SF 54-02 1:250,000 sheet, and on two 1:100,000 map sheets: Marraba 6956 and Cloncurry 7056.')
# Out:
# ...
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/distilroberta-base-modelcard.json' to download model card file.
# Creating an empty model card.
# [{'sequence': '<s> The relinquished portions of EPM 11177 are located south-east and south-west of Perth (see Drawing 333.A4.02) and are within Roxmere Holding (PH 4893)and The Gorge Holding (PH 2330). The relinquished areas lie on the Cloncurry SF 54-02 1:250,000 sheet, and on two 1:100,000 map sheets: Marraba 6956 and Cloncurry 7056.</s>',
#   'score': 0.08063917607069016,
#   'token': 11426},
#  {'sequence': '<s> The relinquished portions of EPM 11177 are located south-east and south-west of Newcastle (see Drawing 333.A4.02) and are within Roxmere Holding (PH 4893)and The Gorge Holding (PH 2330). The relinquished areas lie on the Cloncurry SF 54-02 1:250,000 sheet, and on two 1:100,000 map sheets: Marraba 6956 and Cloncurry 7056.</s>',
#   'score': 0.03402038291096687,
#   'token': 8983},
# ...

# %%
ner = pipeline('ner')
ner('The relinquished portions of EPM 11177 are located south-east and south-west of Cloncurry River (see Drawing 333.A4.02) and are within Roxmere Holding (PH 4893)and The Gorge Holding (PH 2330). The relinquished areas lie on the Cloncurry SF 54-02 1:250,000 sheet, and on two 1:100,000 map sheets: Marraba 6956 and Cloncurry 7056.')
# Out:
# ...
# Model name 'dbmdz/bert-large-cased-finetuned-conll03-english' was not found in model name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-japanese, bert-base-japanese-whole-word-masking, bert-base-japanese-char, bert-base-japanese-char-whole-word-masking, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased, bart-large, bart-large-mnli, bart-cnn, openai-gpt, transfo-xl-wt103, gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2, ctrl, xlnet-base-cased, xlnet-large-cased, xlm-mlm-en-2048, xlm-mlm-ende-1024, xlm-mlm-enfr-1024, xlm-mlm-enro-1024
# ...

# %%
import os

proxies = {
    "http": os.environ['http_proxy'],
    "https": os.environ['https_proxy']
}

# %%
new = pipeline('ner', proxies=proxies)#, model='bert-large-uncased', tokenizer=BertTokenizer)
new('Work completed on the relinquished area included stream sediment sampling, which was part of a regional program that collected samples for BLEG and multi-element analysis. A total of three stream sites were sampled on the relinquished area.')
# Out:
# ...
# Model name 'dbmdz/bert-large-cased-finetuned-conll03-english' was not found in model name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-japanese, bert-base-japanese-whole-word-masking, bert-base-japanese-char, bert-base-japanese-char-whole-word-masking, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased, bart-large, bart-large-mnli, bart-cnn, openai-gpt, transfo-xl-wt103, gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2, ctrl, xlnet-base-cased, xlnet-large-cased, xlm-mlm-en-2048, xlm-mlm-ende-1024, xlm-mlm-enfr-1024, xlm-mlm-enro-1024
# ...
