# %%
import heading_id_intext as hii
import heading_id_toc as hit
import active_learning as al
import settings
# Out:
# Using TensorFlow backend.

# %%
hit.create_dataset()

# %%
hit.train(n_queries=30)
# Out:
# [0.2975983321666717 0.5370596051216125 'cyfra1  \tAnalytical Data']
# <PIL.Image.Image image mode=RGB size=1649x779 at 0x2CEBB47E7B8>
# reports/QDEX/23732/cr_23732_1_page3.png
# line:  16
# queries:  30
# predict proba of this sample:  [[0.4623895  0.36501646 0.1725941 ]]
# Prediction:  [0]
#
# Enter one of:  [0.0, 1.0, 2.0]
# 0
# (830,) cyfra1 punkt  	CST EXPLORATION YEARS 1 - 5 (16/07/2010-15/07/2015) cyfra1
# (830,) cyfra1 punkt  	CST EXPLORATION YEARS 1 - 5 (16/07/2010-15/07/2015) cyfra1
# [Pipeline] .............. (step 1 of 3) Processing text, total=   0.0s
# [Pipeline] ............. (step 2 of 3) Processing split, total=   0.0s
# Train on 664 samples, validate on 166 samples
# Epoch 1/20
# 664/664 [==============================] - 7s 11ms/step - loss: 1.0820 - acc: 0.4187 - val_loss: 1.0483 - val_acc: 0.6988
# Epoch 2/20
# 664/664 [==============================] - 3s 4ms/step - loss: 1.0056 - acc: 0.6220 - val_loss: 0.9483 - val_acc: 0.7530
# Epoch 3/20
# ...

# %%
al.automatically_tag('heading_id_toc', hit.get_toc_headings, 'Heading')
# Out:
# [[9.9869895e-01 1.0410234e-03 2.6006356e-04]
#  [9.8393852e-01 1.4784984e-02 1.2765421e-03]
#  [1.9289526e-01 6.8684369e-01 1.2026108e-01]
#  ...
#  [9.9979252e-01 1.5399524e-04 5.3510230e-05]
#  [4.3864113e-01 5.2639604e-01 3.4962893e-02]
#  [3.8513646e-01 5.7362169e-01 4.1241944e-02]]
# 3376  automatically tagged

# %%
df = hit.create_identification_dataset()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-980622f09fef> in <module>
# ----> 1 df = hit.create_identification_dataset()
#
# ~\Documents\gsq-boreholes\textracting\heading_id_toc.py in create_identification_dataset(datafile)
#     245     lines_docs = sorted(glob.glob('training/restructpageinfo/*'))
#     246     toc_df = pd.read_csv(settings.get_dataset_path('toc'))
# --> 247     toc_pages = get_toc_pages(toc_df)
#     248     for lines_doc in lines_docs:
#     249         pages = json.load(open(lines_doc))
#
# ~\Documents\gsq-boreholes\textracting\toc_classification.py in get_toc_pages(df, mode)
#     107
#     108 def get_toc_pages(df, mode=settings.dataset_version):
# --> 109     return mlh.get_classified(df, name, y_column, limit_cols, mode)
#     110
#     111
#
# ...

# %%
df = hii.create_dataset()
df.to_csv_
hii.train()

# %%
import marginals_classification as mc
mc.train()
# Out:
# [1.51000000e+02 9.71428571e-01 1.00000000e+00 2.88895190e-01
#  2.88895190e-01 1.31568410e-02 6.88824500e-03 9.76308167e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.96637384e-01]
# <PIL.Image.Image image mode=RGB size=1650x733 at 0x1B18A3B5E10>
# reports/QDEX/80420/cr_80420_1_page151.png
# line:  35.0
# queries:  10
# predict proba of this sample:  [[0.5 0.5]]
# Prediction:  [0]
#
# Enter one of:  [ 0.  1. nan]
# 0
# [[8220   12]
#  [   1  267]]
# 0.9984705882352941
# End of training stage. Re-run to train again
# 0.9984705882352941
