# %%
import pandas as pd
prev = 'tables_dataset_prev.csv'
new = 'tables_dataset.csv'

# %%
prevdf = pd.read_csv(prev)
newdf = pd.read_csv(new)

# %%
prevdf.head()
# Out:
#     DocID  TableNum                                            Columns  Class  \
# 0   593.0       1.0      ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']    0.0
# 1   593.0       2.0  ['Adamson, C.L. ', 'Geological Report on the P...    0.0
# 2  1229.0       1.0  ['Bendaaticeras ', 'flindersi ', 'Cephineceras...    0.0
# 3  1229.0       2.0  ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...    0.0
# 4  2646.0       1.0  ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...    0.0
#
#   TagMethod
# 0    manual
# 1    manual
# 2    manual
# 3    manual
# 4    manual

# %%
newdf, prevdf
# Out:
# (        DocID  TableNum                                            Columns
#  0      100291         1  ['Author: ', 'JM. Manning , J. Osborne ', 'Dat...
#  1      100291         2  ['Figure 1: 32 Sub-Blocks comprising EPC994 "S...
#  2      100291         3  ['INTRODUCTION 4 ', 'TENURE 5 ', 'LOCATION, AC...
#  3      100291         4  ['BIM ', 'Block ', 'SUB-BLOCK ', 'AMOUNT ', 'R...
#  4      100291         5  ['ROCK2956 ', 'T U ', 'V ', 'W ', 'X ', 'D ', ...
#  ...       ...       ...                                                ...
#  12580   99816         4  ['NORM 2136 N ', 'NORM 2136 ', 'NORM 2136 P ',...
#  12581   99816         5  ['BIM ', 'Block ', 'Sub-blocks ', 'NORM ', 'Q ...
#  12582   99816         6  ['NORM 2136 O ', 'NORM 2136 P ', 'NORM 2137 L ...
#  12583   99816         7  ['Age ', 'Unit ', 'Lithology ', 'Cainozoic ', ...
#  12584   99816         8                   ['AN19 ', 'X ', 'X ', 'Legend ']
#
#  [12585 rows x 3 columns],
#            DocID  TableNum                                            Columns  \
#  0         593.0       1.0      ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']
#  1         593.0       2.0  ['Adamson, C.L. ', 'Geological Report on the P...
#  2        1229.0       1.0  ['Bendaaticeras ', 'flindersi ', 'Cephineceras...
#  3        1229.0       2.0  ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...
#  4        2646.0       1.0  ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...
#  ...         ...       ...                                                ...
#  1048570     NaN       NaN                                                NaN
#  1048571     NaN       NaN                                                NaN
#  1048572     NaN       NaN                                                NaN
#  1048573     NaN       NaN                                                NaN
#  1048574     NaN       NaN                                                NaN
#
#           Class TagMethod
#  0          0.0    manual
#  1          0.0    manual
#  2          0.0    manual
#  3          0.0    manual
#  4          0.0    manual
#  ...        ...       ...
#  1048570    NaN       NaN
#  1048571    NaN       NaN
#  1048572    NaN       NaN
#  1048573    NaN       NaN
#  1048574    NaN       NaN
#
#  [1048575 rows x 5 columns])

# %%
data = pd.merge(prevdf, newdf, on=['DocID', 'TableNum'], how='outer')
data
# Out:
#            DocID  TableNum                                          Columns_x  \
# 0          593.0       1.0      ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']
# 1          593.0       2.0  ['Adamson, C.L. ', 'Geological Report on the P...
# 2         1229.0       1.0  ['Bendaaticeras ', 'flindersi ', 'Cephineceras...
# 3         1229.0       2.0  ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...
# 4         2646.0       1.0  ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...
# ...          ...       ...                                                ...
# 1056536  99683.0       5.0                                                NaN
# 1056537  99683.0       6.0                                                NaN
# 1056538  99683.0       7.0                                                NaN
# 1056539  99683.0       8.0                                                NaN
# 1056540  99683.0       9.0                                                NaN
#
#          Class TagMethod                                          Columns_y
# 0          0.0    manual      ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']
# 1          0.0    manual  ['Adamson, C.L. ', 'Geological Report on the P...
# 2          0.0    manual  ['Bendaaticeras ', 'flindersi ', 'Cephineceras...
# 3          0.0    manual  ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...
# 4          0.0    manual  ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...
# ...        ...       ...                                                ...
# 1056536    NaN       NaN  ['BIM ', 'Block ', 'Sub-blocks ', 'Clon ', 'e ...
# 1056537    NaN       NaN  ['Hole Id ', 'East MGA94 ', 'North MGA94 ', 'A...
# 1056538    NaN       NaN  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
# 1056539    NaN       NaN  ['Hole ID ', 'Easting MGA54 ', 'Northing MGA54...
# 1056540    NaN       NaN  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
#
# [1056541 rows x 6 columns]

# %%
data
# Out:
#            DocID  TableNum  Class TagMethod  \
# 0          593.0       1.0    0.0    manual
# 1          593.0       2.0    0.0    manual
# 2         1229.0       1.0    0.0    manual
# 3         1229.0       2.0    0.0    manual
# 4         2646.0       1.0    0.0    manual
# ...          ...       ...    ...       ...
# 1056536  99683.0       5.0    NaN       NaN
# 1056537  99683.0       6.0    NaN       NaN
# 1056538  99683.0       7.0    NaN       NaN
# 1056539  99683.0       8.0    NaN       NaN
# 1056540  99683.0       9.0    NaN       NaN
#
#                                                    Columns
# 0            ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']
# 1        ['Adamson, C.L. ', 'Geological Report on the P...
# 2        ['Bendaaticeras ', 'flindersi ', 'Cephineceras...
# 3        ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...
# 4        ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...
# ...                                                    ...
# 1056536  ['BIM ', 'Block ', 'Sub-blocks ', 'Clon ', 'e ...
# 1056537  ['Hole Id ', 'East MGA94 ', 'North MGA94 ', 'A...
# 1056538  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
# 1056539  ['Hole ID ', 'Easting MGA54 ', 'Northing MGA54...
# 1056540  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
#
# [1056541 rows x 5 columns]

# %%
#data.apply(lambda x: x.Columns_x == x.Columns_y )
data['Columns_x'].loc[(data['Columns_y'] == data['Columns_y'] ) & (data['Columns_x'] != data['Columns_y'])] = data['Columns_y']

# %%
data['Columns_x'].loc[(data['Columns_y'] == data['Columns_y'] ) & (data['Columns_x'] != data['Columns_y'])]
# Out:
# 1048575    NaN
# 1048576    NaN
# 1048577    NaN
# 1048578    NaN
# 1048579    NaN
#           ...
# 1056536    NaN
# 1056537    NaN
# 1056538    NaN
# 1056539    NaN
# 1056540    NaN
# Name: Columns_x, Length: 7966, dtype: object

# %%
data['Columns'] = data['Columns_x']
data = data.drop(['Columns_x', 'Columns_y'], axis=1)

# %%
data.dropna(subset=['Columns'])
# Out:
#            DocID  TableNum  Class TagMethod  \
# 0          593.0       1.0    0.0    manual
# 1          593.0       2.0    0.0    manual
# 2         1229.0       1.0    0.0    manual
# 3         1229.0       2.0    0.0    manual
# 4         2646.0       1.0    0.0    manual
# ...          ...       ...    ...       ...
# 1056536  99683.0       5.0    NaN       NaN
# 1056537  99683.0       6.0    NaN       NaN
# 1056538  99683.0       7.0    NaN       NaN
# 1056539  99683.0       8.0    NaN       NaN
# 1056540  99683.0       9.0    NaN       NaN
#
#                                                    Columns
# 0            ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']
# 1        ['Adamson, C.L. ', 'Geological Report on the P...
# 2        ['Bendaaticeras ', 'flindersi ', 'Cephineceras...
# 3        ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...
# 4        ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...
# ...                                                    ...
# 1056536  ['BIM ', 'Block ', 'Sub-blocks ', 'Clon ', 'e ...
# 1056537  ['Hole Id ', 'East MGA94 ', 'North MGA94 ', 'A...
# 1056538  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
# 1056539  ['Hole ID ', 'Easting MGA54 ', 'Northing MGA54...
# 1056540  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
#
# [12885 rows x 5 columns]

# %%
data = data.dropna(subset=['Columns'])

# %%
data.loc[data['Columns_y'] != data['Columns_y']]
# Out:
#            DocID  TableNum                                          Columns_x  \
# 828      42688.0       1.0  ['Tipperary WELL COMPLETION REPORT ', 'Santos ...
# 829      42688.0       2.0  ['AGE ', 'FORMATION ', 'R.T. DEPTHS (m) ', 'MS...
# 830      42688.0       3.0  ['Coal ', 'Top (m RT) ', 'Base (m RT) ', 'Gros...
# 831      42688.0       4.0  ['Location: ', 'Latitude: ', 'Status: ', 'Case...
# 832      42688.0       5.0  ['Type Log ', 'Run ', 'Interval ', 'Max. BHT '...
# ...          ...       ...                                                ...
# 1048570      NaN       NaN                                                NaN
# 1048571      NaN       NaN                                                NaN
# 1048572      NaN       NaN                                                NaN
# 1048573      NaN       NaN                                                NaN
# 1048574      NaN       NaN                                                NaN
#
#          Class TagMethod Columns_y
# 828        NaN      auto       NaN
# 829        NaN      auto       NaN
# 830        NaN      auto       NaN
# 831        NaN      auto       NaN
# 832        NaN      auto       NaN
# ...        ...       ...       ...
# 1048570    NaN       NaN       NaN
# 1048571    NaN       NaN       NaN
# 1048572    NaN       NaN       NaN
# 1048573    NaN       NaN       NaN
# 1048574    NaN       NaN       NaN
#
# [1043956 rows x 6 columns]

# %%
data.loc[data['Columns_x'] != data['Columns_x']]
# Out:
#            DocID  TableNum Columns_x  Class TagMethod  \
# 4919         NaN       NaN       NaN    NaN       NaN
# 4920         NaN       NaN       NaN    NaN       NaN
# 4921         NaN       NaN       NaN    NaN       NaN
# 4922         NaN       NaN       NaN    NaN       NaN
# 4923         NaN       NaN       NaN    NaN       NaN
# ...          ...       ...       ...    ...       ...
# 1056536  99683.0       5.0       NaN    NaN       NaN
# 1056537  99683.0       6.0       NaN    NaN       NaN
# 1056538  99683.0       7.0       NaN    NaN       NaN
# 1056539  99683.0       8.0       NaN    NaN       NaN
# 1056540  99683.0       9.0       NaN    NaN       NaN
#
#                                                  Columns_y
# 4919                                                   NaN
# 4920                                                   NaN
# 4921                                                   NaN
# 4922                                                   NaN
# 4923                                                   NaN
# ...                                                    ...
# 1056536  ['BIM ', 'Block ', 'Sub-blocks ', 'Clon ', 'e ...
# 1056537  ['Hole Id ', 'East MGA94 ', 'North MGA94 ', 'A...
# 1056538  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
# 1056539  ['Hole ID ', 'Easting MGA54 ', 'Northing MGA54...
# 1056540  ['O ', 'ECP001 ECR0003 ', 'O ', 'ANP05 ECR0002...
#
# [1051622 rows x 6 columns]

# %%
while data.shape[0] > 1048576:
    data = data.drop

# %%
data[:-10000]
# Out:
#           DocID  TableNum                                          Columns_x  \
# 0         593.0       1.0      ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']
# 1         593.0       2.0  ['Adamson, C.L. ', 'Geological Report on the P...
# 2        1229.0       1.0  ['Bendaaticeras ', 'flindersi ', 'Cephineceras...
# 3        1229.0       2.0  ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...
# 4        2646.0       1.0  ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...
# ...         ...       ...                                                ...
# 1046536     NaN       NaN                                                NaN
# 1046537     NaN       NaN                                                NaN
# 1046538     NaN       NaN                                                NaN
# 1046539     NaN       NaN                                                NaN
# 1046540     NaN       NaN                                                NaN
#
#          Class TagMethod                                          Columns_y
# 0          0.0    manual      ['RIVERS ', 'INNER ', 'by ', 'G. ', 'Rose. ']
# 1          0.0    manual  ['Adamson, C.L. ', 'Geological Report on the P...
# 2          0.0    manual  ['Bendaaticeras ', 'flindersi ', 'Cephineceras...
# 3          0.0    manual  ['Laing, ', 'A.C.M. ', 'and Powr, P.L. 1960. C...
# 4          0.0    manual  ['Page ', 'OBJECTIVES ', 'DRILLING ', 'GEOLOGY...
# ...        ...       ...                                                ...
# 1046536    NaN       NaN                                                NaN
# 1046537    NaN       NaN                                                NaN
# 1046538    NaN       NaN                                                NaN
# 1046539    NaN       NaN                                                NaN
# 1046540    NaN       NaN                                                NaN
#
# [1046541 rows x 6 columns]

# %%
data.to_csv('tables_dataset_appended.csv', index=False)
